# %% [markdown]
# # COVID-19 Literature Clustering

# %% [markdown]
# ### Goal
# Given a large amount of literature and rapidly spreading COVID-19, it is difficult for a scientist to keep up with the research community promptly. Can we cluster similar research articles together to make it easier for health professionals to find relevant research articles? Clustering can be used to create a tool to identify similar articles, given a target article. It can also reduce the number of articles one has to go through as one can focus on a cluster of articles rather than all.
#
# **Approach**:
# <ol>
#     <li>Unsupervised Learning task, because we don't have labels for the articles</li>
#     <li>Clustering and Dimensionality Reduction task </li>
#     <li>See how well labels from K-Means classify</li>
#     <li>Use N-Grams with Hash Vectorizer</li>
#     <li>Use plain text with Tf-idf</li>
#     <li>Use K-Means for clustering</li>
#     <li>Use t-SNE for dimensionality reduction</li>
#     <li>Use PCA for dimensionality reduction</li>
#     <li>There is no continuous flow of data, no need to adjust to changing data, and the data is small enough to fit in memmory: Batch Learning</li>
#     <li>Altough, there is no continuous flow of data, our approach has to be scalable as there will be more literature later</li>
# </ol>
#
# ### Dataset Description
#
# >*In response to the COVID-19 pandemic, the White House and a coalition of leading research groups have prepared the COVID-19 Open Research Dataset (CORD-19). CORD-19 is a resource of over 29,000 scholarly articles, including over 13,000 with full text, about COVID-19, SARS-CoV-2, and related coronaviruses. This freely available dataset is provided to the global research community to apply recent advances in natural language processing and other AI techniques to generate new insights in support of the ongoing fight against this infectious disease. There is a growing urgency for these approaches because of the rapid acceleration in new coronavirus literature, making it difficult for the medical research community to keep up.*
# #### Cite: [COVID-19 Open Research Dataset Challenge (CORD-19) | Kaggle](https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge) <br>

# %% [markdown]
# # Load the Data
# Load the data following the notebook by Ivan Ega Pratama, from Kaggle.
# #### Cite: [Dataset Parsing Code | Kaggle, COVID EDA: Initial Exploration Tool](https://www.kaggle.com/ivanegapratama/covid-eda-initial-exploration-tool)

# %% [markdown]
# ### Loading Metadata

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import json

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Let's load the metadata of the dateset. 'title' and 'journal' attributes may be useful later when we cluster the articles to see what kinds of articles cluster together.

# %%
# root_path = 'CORD-19-research-challenge/'
root_path = '.'
metadata_path = f'{root_path}/metadata.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
meta_df.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  xqhn0vbp  1e1286db212100993d03cc22374b624f7caee956      PMC
# 1  gi6uaa83  8ae137c8da1607b3a8e4c946c07ca8bda67f88ac      PMC
# 2  le0ogx1s                                       NaN      PMC
# 3  fy4w7xz8  0104f6ceccf92ae8567a0102f89cbb976969a774      PMC
# 4  0qaoam29  5b68a553a7cbbea13472721cd1ad617d42b40c26      PMC
#
#                                                title                      doi  \
# 0  Airborne rhinovirus detection and effect of ul...    10.1186/1471-2458-3-5
# 1    Discovering human history from stomach bacteria  10.1186/gb-2003-4-5-213
# 2     A new recruit for the army of the men of death  10.1186/gb-2003-4-7-113
# 3  Association of HLA class I with severe acute r...    10.1186/1471-2350-4-9
# 4   A double epidemic model for the SARS propagation   10.1186/1471-2334-3-19
#
#        pmcid pubmed_id license  \
# 0  PMC140314  12525263   no-cc
# 1  PMC156578  12734001   no-cc
# 2  PMC193621  12844350   no-cc
# 3  PMC212558  12969506   no-cc
# 4  PMC222908  12964944   no-cc
#
#                                             abstract publish_time  \
# 0  BACKGROUND: Rhinovirus, the most common cause ...   2003-01-13
# 1  Recent analyses of human pathogens have reveal...   2003-04-28
# 2  The army of the men of death, in John Bunyan's...   2003-06-27
# 3  BACKGROUND: The human leukocyte antigen (HLA) ...   2003-09-12
# 4  BACKGROUND: An epidemic of a Severe Acute Resp...   2003-09-10
#
#                                              authors            journal  \
# 0  Myatt, Theodore A; Johnston, Sebastian L; Rudn...  BMC Public Health
# 1                                   Disotell, Todd R        Genome Biol
# 2                                  Petsko, Gregory A        Genome Biol
# 3  Lin, Marie; Tseng, Hsiang-Kuang; Trejaut, Jean...      BMC Med Genet
# 4  Ng, Tuen Wai; Turinici, Gabriel; Danchin, Antoine     BMC Infect Dis
#
#   Microsoft Academic Paper ID WHO #Covidence  has_pdf_parse  \
# 0                         NaN            NaN           True
# 1                         NaN            NaN           True
# 2                         NaN            NaN          False
# 3                         NaN            NaN           True
# 4                         NaN            NaN           True
#
#    has_pmc_xml_parse  full_text_file  \
# 0               True  custom_license
# 1               True  custom_license
# 2               True  custom_license
# 3               True  custom_license
# 4               True  custom_license
#
#                                                  url
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51078 entries, 0 to 51077
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cord_uid                     51078 non-null  object
#  1   sha                          38022 non-null  object
#  2   source_x                     51078 non-null  object
#  3   title                        50920 non-null  object
#  4   doi                          47741 non-null  object
#  5   pmcid                        41082 non-null  object
#  6   pubmed_id                    37861 non-null  object
#  7   license                      51078 non-null  object
#  8   abstract                     42352 non-null  object
#  9   publish_time                 51070 non-null  object
#  10  authors                      48891 non-null  object
#  11  journal                      46368 non-null  object
#  12  Microsoft Academic Paper ID  964 non-null    object
#  13  WHO #Covidence               1768 non-null   object
#  14  has_pdf_parse                51078 non-null  bool
#  15  has_pmc_xml_parse            51078 non-null  bool
#  16  full_text_file               42511 non-null  object
#  17  url                          50776 non-null  object
# dtypes: bool(2), object(16)
# memory usage: 6.3+ MB

# %% [markdown]
# ### Fetch All of JSON File Path

# %% [markdown]
# Get path to all JSON files:

# %%
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
len(all_json)
# Out:
# 45928

# %% [markdown]
# ### Helper Functions

# %% [markdown]
#  File Reader Class

# %%
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id']
            self.abstract = []
            self.body_text = []
            # Abstract
            for entry in content['abstract']:
                self.abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])
            self.abstract = '\n'.join(self.abstract)
            self.body_text = '\n'.join(self.body_text)
    def __repr__(self):
        return f'{self.paper_id}: {self.abstract[:200]}... {self.body_text[:200]}...'
    
# Helper function adds break after every words when character length reach to certain amount. This is for the interactive plot so that hover tool fits the screen.
    
def get_breaks(content, length):
    data = ""
    words = content.split(' ')
    total_chars = 0

    # add break every length characters
    for i in range(len(words)):
        total_chars += len(words[i])
        if total_chars > length:
            data = data + "<br>" + words[i]
            total_chars = 0
        else:
            data = data + " " + words[i]
    return data

# %% [markdown]
# ### Load the Data into DataFrame

# %% [markdown]
# Using the helper functions, let's read in the articles into a DataFrame that can be used easily:

# %%
dict_ = {'paper_id': [], 'abstract': [], 'body_text': [], 'authors': [], 'title': [], 'journal': [], 'abstract_summary': []}
for idx, entry in enumerate(all_json):
    try:
        if idx % (len(all_json) // 10) == 0:
            print(f'Processing index: {idx} of {len(all_json)}')
        content = FileReader(entry)

        # get metadata information
        meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
        # no metadata, skip this paper
        if len(meta_data) == 0:
            continue

        dict_['paper_id'].append(content.paper_id)
        dict_['abstract'].append(content.abstract)
        dict_['body_text'].append(content.body_text)

        # also create a column for the summary of abstract to be used in a plot
        if len(content.abstract) == 0: 
            # no abstract provided
            dict_['abstract_summary'].append("Not provided.")
        elif len(content.abstract.split(' ')) > 100:
            # abstract provided is too long for plot, take first 300 words append with ...
            info = content.abstract.split(' ')[:100]
            summary = get_breaks(' '.join(info), 40)
            dict_['abstract_summary'].append(summary + "...")
        else:
            # abstract is short enough
            summary = get_breaks(content.abstract, 40)
            dict_['abstract_summary'].append(summary)

        # get metadata information
        meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]

        try:
            # if more than one author
            authors = meta_data['authors'].values[0].split(';')
            if len(authors) > 2:
                # more than 2 authors, may be problem when plotting, so take first 2 append with ...
                dict_['authors'].append(". ".join(authors[:2]) + "...")
            else:
                # authors will fit in plot
                dict_['authors'].append(". ".join(authors))
        except Exception as e:
            # if only one author - or Null valie
            dict_['authors'].append(meta_data['authors'].values[0])

        # add the title information, add breaks when needed
        try:
            title = get_breaks(meta_data['title'].values[0], 40)
            dict_['title'].append(title)
        # if title was not provided
        except Exception as e:
            dict_['title'].append(meta_data['title'].values[0])

        # add the journal information
        dict_['journal'].append(meta_data['journal'].values[0])
        
    
    except Exception as e:
        continue
    
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'abstract', 'body_text', 'authors', 'title', 'journal', 'abstract_summary'])
df_covid.head()
# Out:
# Processing index: 0 of 45928
# Processing index: 4592 of 45928
# Processing index: 9184 of 45928
# Processing index: 13776 of 45928
# Processing index: 18368 of 45928
# Processing index: 22960 of 45928
# Processing index: 27552 of 45928
# Processing index: 32144 of 45928
# Processing index: 36736 of 45928
# Processing index: 41328 of 45928
# Processing index: 45920 of 45928
#                                    paper_id  \
# 0  ffe718db1820f27bf274e3fc519ab78e450de288
# 1  ff83907653a4c4500e8c509ca28169e924742b40
# 2  ff3db609dbf2669d8d528279ef32280c2646ba85
# 3  ff6d57f2aad99be129432058665b361dc18747e8
# 4  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
#
#                                             abstract  \
# 0  We provide experimental evidence of a replicat...
# 1  We have combined in vivo and in vitro approach...
# 2  Because many aspects of viral infection dynami...
# 3  There is extensive evidence that cultured macr...
# 4  Even though coronavirus infection of humans is...
#
#                                            body_text  \
# 0  Tick-borne encephalitis virus (TBEV) is a huma...
# 1  can function in an autonomous fashion, relocat...
# 2  Over the past few decades, the world has witne...
# 3  Experiments were designed to test whether subs...
# 4  Regardless of geographic location, respiratory...
#
#                                      authors  \
# 0               Tuplin, A..  Evans, D. J....
# 1                                        NaN
# 2             Liu, Wu.  Caglar, Mehmet U....
# 3                                        NaN
# 4  Abdul-Rasool, Sahar.  Fielding, Burtram C
#
#                                                title            journal  \
# 0   Replication enhancer elements within the open...  Nucleic Acids Res
# 1   Identification of a subdomain of CENP-B that ...        J Cell Biol
# 2   More than efficacy revealed by single-cell<br...            Sci Adv
# 3   Macrophages genetically resistant to mouse<br...          J Exp Med
# 4          Understanding Human Coronavirus HCoV-NL63       Open Virol J
#
#                                     abstract_summary
# 0   We provide experimental evidence of a<br>repl...
# 1   We have combined in vivo and in vitro approac...
# 2   Because many aspects of viral infection<br>dy...
# 3   There is extensive evidence that cultured<br>...
# 4   Even though coronavirus infection of humans i...

# %%
dict_ = None

# %% [markdown]
# # Adding the Word Count Columns

# %% [markdown]
# Adding word count columns for both abstract and body_text can be useful parameters later:

# %%
df_covid['abstract_word_count'] = df_covid['abstract'].apply(lambda x: len(x.strip().split()))
df_covid['body_word_count'] = df_covid['body_text'].apply(lambda x: len(x.strip().split()))
df_covid.head()
# Out:
#                                    paper_id  \
# 0  ffe718db1820f27bf274e3fc519ab78e450de288
# 1  ff83907653a4c4500e8c509ca28169e924742b40
# 2  ff3db609dbf2669d8d528279ef32280c2646ba85
# 3  ff6d57f2aad99be129432058665b361dc18747e8
# 4  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
#
#                                             abstract  \
# 0  We provide experimental evidence of a replicat...
# 1  We have combined in vivo and in vitro approach...
# 2  Because many aspects of viral infection dynami...
# 3  There is extensive evidence that cultured macr...
# 4  Even though coronavirus infection of humans is...
#
#                                            body_text  \
# 0  Tick-borne encephalitis virus (TBEV) is a huma...
# 1  can function in an autonomous fashion, relocat...
# 2  Over the past few decades, the world has witne...
# 3  Experiments were designed to test whether subs...
# 4  Regardless of geographic location, respiratory...
#
#                                      authors  \
# 0               Tuplin, A..  Evans, D. J....
# 1                                        NaN
# 2             Liu, Wu.  Caglar, Mehmet U....
# 3                                        NaN
# 4  Abdul-Rasool, Sahar.  Fielding, Burtram C
#
#                                                title            journal  \
# 0   Replication enhancer elements within the open...  Nucleic Acids Res
# 1   Identification of a subdomain of CENP-B that ...        J Cell Biol
# 2   More than efficacy revealed by single-cell<br...            Sci Adv
# 3   Macrophages genetically resistant to mouse<br...          J Exp Med
# 4          Understanding Human Coronavirus HCoV-NL63       Open Virol J
#
#                                     abstract_summary  abstract_word_count  \
# 0   We provide experimental evidence of a<br>repl...                  202
# 1   We have combined in vivo and in vitro approac...                  354
# 2   Because many aspects of viral infection<br>dy...                  126
# 3   There is extensive evidence that cultured<br>...                  419
# 4   Even though coronavirus infection of humans i...                  158
#
#    body_word_count
# 0             6035
# 1             7225
# 2             4486
# 3             1339
# 4             3894

# %%
df_covid['abstract'].describe(include='all')
# Out:
# count     27344
# unique    18276
# top
# freq       9019
# Name: abstract, dtype: object

# %% [markdown]
# # Data Pre-processing-Handle Possible Duplicates

# %% [markdown]
# When we look at the unique values above, we can see that there are duplicates. It may have caused because of author submiting the article to multiple journals. Let's remove the duplicats from our dataset:

# %%
df_covid.dropna(inplace=True)
df_covid = df_covid[df_covid.abstract != ''] #Remove rows which are missing abstracts
df_covid = df_covid[df_covid.body_text != ''] #Remove rows which are missing body_text
df_covid.drop_duplicates(['abstract', 'body_text'], inplace=True) # remove duplicate rows having same abstract and body_text
df_covid['abstract'].describe(include='all')
# Out:
# count                                                 16674
# unique                                                16647
# top       Travel Medicine and Infectious Disease xxx (xx...
# freq                                                      5
# Name: abstract, dtype: object

# %%
df_covid['body_text'].describe(include='all')
# Out:
# count                                                 16674
# unique                                                16674
# top       Tick-borne encephalitis virus (TBEV) is a huma...
# freq                                                      1
# Name: body_text, dtype: object

# %% [markdown]
# It looks like we didn't have duplicates. Instead, it was articles without Abstracts.

# %% [markdown]
# # Take a Look at the Data:

# %%
df_covid.head()
# Out:
#                                    paper_id  \
# 0  ffe718db1820f27bf274e3fc519ab78e450de288
# 2  ff3db609dbf2669d8d528279ef32280c2646ba85
# 4  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 5  ff3786e07cdc8f41bc8347c875b84813cbb8d3eb
# 6  ff368c9be888417304869b18575ea6521dcc95b6
#
#                                             abstract  \
# 0  We provide experimental evidence of a replicat...
# 2  Because many aspects of viral infection dynami...
# 4  Even though coronavirus infection of humans is...
# 5  The aim of this study was to evaluate the imag...
# 6  Enteroviruses invade the host by crossing the ...
#
#                                            body_text  \
# 0  Tick-borne encephalitis virus (TBEV) is a huma...
# 2  Over the past few decades, the world has witne...
# 4  Regardless of geographic location, respiratory...
# 5  Immunocompromised patients with underlying hem...
# 6  the viral receptor induces conformational chan...
#
#                                      authors  \
# 0               Tuplin, A..  Evans, D. J....
# 2             Liu, Wu.  Caglar, Mehmet U....
# 4  Abdul-Rasool, Sahar.  Fielding, Burtram C
# 5           Kim, Hae Jin.  Park, So Young...
# 6     Kim, Chonsaeng.  Bergelson, Jeffrey M.
#
#                                                title            journal  \
# 0   Replication enhancer elements within the open...  Nucleic Acids Res
# 2   More than efficacy revealed by single-cell<br...            Sci Adv
# 4          Understanding Human Coronavirus HCoV-NL63       Open Virol J
# 5   Ultra-Low-Dose Chest CT in Patients with<br>N...   Cancer Res Treat
# 6   Echovirus 7 Entry into Polarized Intestinal<b...               mBio
#
#                                     abstract_summary  abstract_word_count  \
# 0   We provide experimental evidence of a<br>repl...                  202
# 2   Because many aspects of viral infection<br>dy...                  126
# 4   Even though coronavirus infection of humans i...                  158
# 5   The aim of this study was to evaluate the ima...                  245
# 6   Enteroviruses invade the host by crossing the...                  332
#
#    body_word_count
# 0             6035
# 2             4486
# 4             3894
# 5             3898
# 6             5118

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16674 entries, 0 to 25718
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             16674 non-null  object
#  1   abstract             16674 non-null  object
#  2   body_text            16674 non-null  object
#  3   authors              16674 non-null  object
#  4   title                16674 non-null  object
#  5   journal              16674 non-null  object
#  6   abstract_summary     16674 non-null  object
#  7   abstract_word_count  16674 non-null  int64
#  8   body_word_count      16674 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 1.3+ MB

# %%
df_covid.describe()
# Out:
#        abstract_word_count  body_word_count
# count         16674.000000     16674.000000
# mean            196.440626      4351.396665
# std             113.066632      4161.371480
# min               1.000000        23.000000
# 25%             136.000000      2539.000000
# 50%             186.000000      3606.500000
# 75%             240.000000      5237.750000
# max            2913.000000    232431.000000

# %% [markdown]
# Now that we have our dataset loaded, we need to clean-up the text to improve any clustering or classification efforts. First, let's drop Null vales:

# %% [markdown]
# Limit number of articles to speed up computation:

# %%
# TA: Feel free to decrease this number if you think your system is getting stuck
df_covid = df_covid.head(5523)

# %% [markdown]
# Now let's remove punctuation from each text:

# %%
import re

df_covid['body_text'] = df_covid['body_text'].apply(lambda x: re.sub('[^a-zA-z0-9\s]','',x))
df_covid['abstract'] = df_covid['abstract'].apply(lambda x: re.sub('[^a-zA-z0-9\s]','',x))

# %% [markdown]
# Convert each text to lower case:

# %%
def lower_case(input_str):
    input_str = input_str.lower()
    return input_str

df_covid['body_text'] = df_covid['body_text'].apply(lambda x: lower_case(x))
df_covid['abstract'] = df_covid['abstract'].apply(lambda x: lower_case(x))

# %%
df_covid.head(4)
# Out:
#                                    paper_id  \
# 0  ffe718db1820f27bf274e3fc519ab78e450de288
# 2  ff3db609dbf2669d8d528279ef32280c2646ba85
# 4  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 5  ff3786e07cdc8f41bc8347c875b84813cbb8d3eb
#
#                                             abstract  \
# 0  we provide experimental evidence of a replicat...
# 2  because many aspects of viral infection dynami...
# 4  even though coronavirus infection of humans is...
# 5  the aim of this study was to evaluate the imag...
#
#                                            body_text  \
# 0  tickborne encephalitis virus tbev is a human p...
# 2  over the past few decades the world has witnes...
# 4  regardless of geographic location respiratory ...
# 5  immunocompromised patients with underlying hem...
#
#                                      authors  \
# 0               Tuplin, A..  Evans, D. J....
# 2             Liu, Wu.  Caglar, Mehmet U....
# 4  Abdul-Rasool, Sahar.  Fielding, Burtram C
# 5           Kim, Hae Jin.  Park, So Young...
#
#                                                title            journal  \
# 0   Replication enhancer elements within the open...  Nucleic Acids Res
# 2   More than efficacy revealed by single-cell<br...            Sci Adv
# 4          Understanding Human Coronavirus HCoV-NL63       Open Virol J
# 5   Ultra-Low-Dose Chest CT in Patients with<br>N...   Cancer Res Treat
#
#                                     abstract_summary  abstract_word_count  \
# 0   We provide experimental evidence of a<br>repl...                  202
# 2   Because many aspects of viral infection<br>dy...                  126
# 4   Even though coronavirus infection of humans i...                  158
# 5   The aim of this study was to evaluate the ima...                  245
#
#    body_word_count
# 0             6035
# 2             4486
# 4             3894
# 5             3898

# %% [markdown]
# Now that we have the text cleaned up, we can create our features vector which can be fed into a clustering or dimensionality reduction algorithm. For our first try, we will focus on the text on the body of the articles. Let's grab that:

# %%
text = df_covid.drop(["paper_id", "abstract", "abstract_word_count", "body_word_count", "authors", "title", "journal", "abstract_summary"], axis=1)

# %%
text.head(5)
# Out:
#                                            body_text
# 0  tickborne encephalitis virus tbev is a human p...
# 2  over the past few decades the world has witnes...
# 4  regardless of geographic location respiratory ...
# 5  immunocompromised patients with underlying hem...
# 6  the viral receptor induces conformational chan...

# %% [markdown]
# Let's transform 1D DataFrame into 1D list where each index is an article (instance), so that we can work with words from each instance:

# %%
text_arr = text.stack().tolist()
len(text_arr)
# Out:
# 5523

# %% [markdown]
# # 2-Grams

# %% [markdown]
# Let's create 2D list, where each row is instance and each column is a word. Meaning, we will separate each instance into words:

# %%
words = []
for ii in range(0,len(text)):
    words.append(str(text.iloc[ii]['body_text']).split(" "))

# %%
print(words[0][:20])
# Out:
# ['tickborne', 'encephalitis', 'virus', 'tbev', 'is', 'a', 'human', 'pathogen', 'that', 'causes', 'about', '16', '000', 'human', 'cases', 'of', 'tickborne', 'encephalitis', 'tbe', 'across']

# %% [markdown]
# What we want now is n-grams from the words where n=2 (2-gram). We will still have 2D array where each row is an instance; however, each index in that row going to be a 2-gram:

# %%
n_gram_all = []

for word in words:
    # get n-grams for the instance
    n_gram = []
    for i in range(len(word)-2+1):
        n_gram.append("".join(word[i:i+2]))
    n_gram_all.append(n_gram)

# %%
n_gram_all[0][:10]
# Out:
# ['tickborneencephalitis',
#  'encephalitisvirus',
#  'virustbev',
#  'tbevis',
#  'isa',
#  'ahuman',
#  'humanpathogen',
#  'pathogenthat',
#  'thatcauses',
#  'causesabout']

# %% [markdown]
# # Vectorize with HashingVectorizer

# %% [markdown]
# Now we will use HashVectorizer to create the features vector X. For now, let's limit the feature size to 2**12(4096) to speed up the computation. We might need to increase this later to reduce the collusions and improve the accuracy:

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# hash vectorizer instance
hvec = HashingVectorizer(lowercase=False, analyzer=lambda l:l, n_features=2**12)

# features matrix X
X = hvec.fit_transform(n_gram_all)

# %%
X.shape
# Out:
# (5523, 4096)

# %% [markdown]
# #### Separete Training and Test Set

# %%
from sklearn.model_selection import train_test_split

# test set size of 20% of the data and the random seed 42 <3
X_train, X_test = train_test_split(X.toarray(), test_size=0.2, random_state=42)

print("X_train size:", len(X_train))
print("X_test size:", len(X_test), "\n")
# Out:
# X_train size: 4418
# X_test size: 1105

# %% [markdown]
# # Dimensionality Reduction with t-SNE
# Using t-SNE we can reduce our high dimensional features vector into 2 dimensional plane. In the process, t-SNE will keep similar instances together while trying to push different instances far from each other. Resulting 2-D plane can be useful to see which articles cluster near each other:

# %%
# Following cell will take 15-20 minutes to run

from sklearn.manifold import TSNE

tsne = TSNE(verbose=1, perplexity=5)
X_embedded = tsne.fit_transform(X_train)
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sched\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 4418 samples in 0.021s...
# [t-SNE] Computed neighbors for 4418 samples in 1.102s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4418
# [t-SNE] Computed conditional probabilities for sample 2000 / 4418
# [t-SNE] Computed conditional probabilities for sample 3000 / 4418
# [t-SNE] Computed conditional probabilities for sample 4000 / 4418
# [t-SNE] Computed conditional probabilities for sample 4418 / 4418
# [t-SNE] Mean sigma: 0.130913
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 142.334473
# [t-SNE] KL divergence after 1000 iterations: 3.544987

# %% [markdown]
# Let's plot the result:

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", 1)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], palette=palette)

plt.title("t-SNE Covid-19 Articles")
# plt.savefig("plots/t-sne_covid19.png")
plt.show()
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# We can clearly see few clusters forming. This may be a good sign that we are able to cluster similar articles together using 2-grams and HashVectorizer with 2**10 features. However, without labels it is difficult to see the clusters. For now, it looks like a blob of data... Let's try if we can use K-Means to generate our labels. We can later use this information to produce a scatterplot with labels to verify the clusters.

# %% [markdown]
# # Unsupervised Learning: Clustering with K-Means

# %% [markdown]
# Using K-means we will get the labels we need. For now, we will create 10 clusters. I am choosing this arbitrarily. We can change this later.

# %%
# Following cell will take 4-5 minutes to run

from sklearn.cluster import KMeans

k = 10
kmeans = KMeans(n_clusters=k, verbose=10)
y_pred = kmeans.fit_predict(X_train)
# Out:
# Initialization complete
# Iteration 0, inertia 6082.406179242687
# Iteration 1, inertia 3378.2716503269658
# Iteration 2, inertia 3346.2159032344653
# Iteration 3, inertia 3338.861661406641
# Iteration 4, inertia 3335.2365447447105
# Iteration 5, inertia 3332.2157329944207
# Iteration 6, inertia 3329.953734274347
# Iteration 7, inertia 3328.3791451094194
# Iteration 8, inertia 3327.7658339158415
# Iteration 9, inertia 3327.3341478485186
# Iteration 10, inertia 3327.060512981875
# Iteration 11, inertia 3326.8588241674624
# Iteration 12, inertia 3326.7434237116163
# Iteration 13, inertia 3326.6633017966287
# Iteration 14, inertia 3326.6058069783558
# Iteration 15, inertia 3326.5584304999043
# Iteration 16, inertia 3326.514066839866
# Iteration 17, inertia 3326.480381565808
# Iteration 18, inertia 3326.4384796001714
# Iteration 19, inertia 3326.4114603040853
# Iteration 20, inertia 3326.3837955852587
# Iteration 21, inertia 3326.3720719934654
# Iteration 22, inertia 3326.355278816391
# Iteration 23, inertia 3326.3476434949152
# Iteration 24, inertia 3326.3415538019867
# Iteration 25, inertia 3326.3375473133724
# Iteration 26, inertia 3326.3357770013636
# Converged at iteration 26: strict convergence.
# Initialization complete
# Iteration 0, inertia 6043.64567687368
# Iteration 1, inertia 3389.4915312411176
# Iteration 2, inertia 3358.419843832252
# Iteration 3, inertia 3346.636721346524
# Iteration 4, inertia 3340.2753255879375
# Iteration 5, inertia 3337.385391077761
# Iteration 6, inertia 3335.9543188620455
# Iteration 7, inertia 3335.142003181709
# Iteration 8, inertia 3334.505968896958
# Iteration 9, inertia 3333.821264342599
# Iteration 10, inertia 3333.081617935759
# Iteration 11, inertia 3332.472758700742
# Iteration 12, inertia 3332.1305108975575
# Iteration 13, inertia 3331.9550261402346
# Iteration 14, inertia 3331.8294857989667
# Iteration 15, inertia 3331.7138105520467
# Iteration 16, inertia 3331.6357132545872
# Iteration 17, inertia 3331.560212480503
# Iteration 18, inertia 3331.509322159026
# Iteration 19, inertia 3331.475592752042
# Iteration 20, inertia 3331.4390452085368
# Iteration 21, inertia 3331.3902648598405
# Iteration 22, inertia 3331.3457240982048
# Iteration 23, inertia 3331.300774461437
# Iteration 24, inertia 3331.2628989917007
# Iteration 25, inertia 3331.2424449919536
# Iteration 26, inertia 3331.228937096074
# Iteration 27, inertia 3331.219456022708
# Iteration 28, inertia 3331.2121931178267
# Iteration 29, inertia 3331.205028031641
# Iteration 30, inertia 3331.2015159718817
# Iteration 31, inertia 3331.191510175273
# Iteration 32, inertia 3331.1820737487897
# Iteration 33, inertia 3331.170387773039
# Iteration 34, inertia 3331.1487840543455
# Iteration 35, inertia 3331.135733618005
# Iteration 36, inertia 3331.1173443876196
# Iteration 37, inertia 3331.0982724803075
# Iteration 38, inertia 3331.0772775175137
# Iteration 39, inertia 3331.0566255182207
# Iteration 40, inertia 3331.03560103758
# Iteration 41, inertia 3331.01138273385
# Iteration 42, inertia 3330.9829423761475
# Iteration 43, inertia 3330.953997666897
# Iteration 44, inertia 3330.934670500373
# Iteration 45, inertia 3330.919074982019
# Iteration 46, inertia 3330.9084801685926
# Iteration 47, inertia 3330.9012474811507
# Iteration 48, inertia 3330.895651538277
# Iteration 49, inertia 3330.893172597251
# Iteration 50, inertia 3330.8902694562476
# Iteration 51, inertia 3330.8842248799965
# Iteration 52, inertia 3330.8808891694116
# Converged at iteration 52: strict convergence.
# Initialization complete
# Iteration 0, inertia 6045.394675710402
# Iteration 1, inertia 3375.0654661425656
# Iteration 2, inertia 3344.9411337949705
# Iteration 3, inertia 3333.829372119809
# Iteration 4, inertia 3328.4913961717566
# Iteration 5, inertia 3325.750681718105
# Iteration 6, inertia 3324.4881812169106
# Iteration 7, inertia 3323.6848750612276
# Iteration 8, inertia 3323.148141576857
# Iteration 9, inertia 3322.808459664418
# Iteration 10, inertia 3322.602569522791
# Iteration 11, inertia 3322.42935750921
# Iteration 12, inertia 3322.3077614977183
# Iteration 13, inertia 3322.2386703537695
# Iteration 14, inertia 3322.191196543847
# Iteration 15, inertia 3322.1317965478374
# Iteration 16, inertia 3322.082900803749
# Iteration 17, inertia 3322.0625803267417
# Iteration 18, inertia 3322.0532282092663
# Iteration 19, inertia 3322.0402047246143
# Iteration 20, inertia 3322.0206833701045
# Iteration 21, inertia 3322.00190397356
# Iteration 22, inertia 3321.993218282949
# Iteration 23, inertia 3321.9817809586784
# Iteration 24, inertia 3321.9730701757935
# Iteration 25, inertia 3321.9675070004373
# Iteration 26, inertia 3321.9622314118246
# Converged at iteration 26: strict convergence.
# Initialization complete
# Iteration 0, inertia 5808.1939048785725
# Iteration 1, inertia 3387.067101308023
# Iteration 2, inertia 3360.112576385475
# Iteration 3, inertia 3350.002196268399
# Iteration 4, inertia 3345.4802828589727
# Iteration 5, inertia 3343.350741182872
# Iteration 6, inertia 3341.926327604071
# Iteration 7, inertia 3339.664847917298
# Iteration 8, inertia 3337.7589175027656
# Iteration 9, inertia 3336.281337671032
# Iteration 10, inertia 3335.1899168918003
# Iteration 11, inertia 3333.0010714635564
# Iteration 12, inertia 3330.5487461318057
# Iteration 13, inertia 3329.530891841673
# Iteration 14, inertia 3329.427252195141
# Iteration 15, inertia 3329.3829689837535
# Iteration 16, inertia 3329.3437118525344
# Iteration 17, inertia 3329.3130136850723
# Iteration 18, inertia 3329.3036944833725
# Iteration 19, inertia 3329.301057139981
# Converged at iteration 19: strict convergence.
# Initialization complete
# Iteration 0, inertia 5951.814746791372
# Iteration 1, inertia 3388.814641159877
# Iteration 2, inertia 3352.5105532892712
# Iteration 3, inertia 3340.2127079058173
# Iteration 4, inertia 3335.0826816676185
# Iteration 5, inertia 3332.4780103960684
# Iteration 6, inertia 3330.539423979379
# Iteration 7, inertia 3328.1673758355673
# Iteration 8, inertia 3325.3062554569356
# Iteration 9, inertia 3321.29370731414
# Iteration 10, inertia 3318.527150307802
# Iteration 11, inertia 3317.8915411223184
# Iteration 12, inertia 3317.5159744082002
# Iteration 13, inertia 3317.206868760985
# Iteration 14, inertia 3317.0249863820154
# Iteration 15, inertia 3316.8955358331978
# Iteration 16, inertia 3316.8293018487293
# Iteration 17, inertia 3316.7912359436164
# Iteration 18, inertia 3316.7686733195374
# Iteration 19, inertia 3316.747264493362
# Iteration 20, inertia 3316.733864057051
# Converged at iteration 20: strict convergence.
# Initialization complete
# Iteration 0, inertia 5949.74558384558
# Iteration 1, inertia 3390.33010566352
# Iteration 2, inertia 3358.1755223089067
# Iteration 3, inertia 3343.471414442958
# Iteration 4, inertia 3336.7882663505757
# Iteration 5, inertia 3334.272443976144
# Iteration 6, inertia 3332.940049585307
# Iteration 7, inertia 3331.902589931483
# Iteration 8, inertia 3331.091266726206
# Iteration 9, inertia 3330.3397871177317
# Iteration 10, inertia 3329.4721381068593
# Iteration 11, inertia 3328.900501840147
# Iteration 12, inertia 3328.374739727684
# Iteration 13, inertia 3328.071249682718
# Iteration 14, inertia 3327.8056685923457
# Iteration 15, inertia 3327.62109484555
# Iteration 16, inertia 3327.4797729680886
# Iteration 17, inertia 3327.379457874975
# Iteration 18, inertia 3327.3332439744427
# Iteration 19, inertia 3327.3014894899106
# Iteration 20, inertia 3327.286904631731
# Iteration 21, inertia 3327.2741132205006
# Iteration 22, inertia 3327.271047793073
# Iteration 23, inertia 3327.2687143777816
# Converged at iteration 23: strict convergence.
# Initialization complete
# Iteration 0, inertia 6101.928842421773
# Iteration 1, inertia 3387.8684769627894
# Iteration 2, inertia 3346.3045912364237
# Iteration 3, inertia 3333.716977356459
# Iteration 4, inertia 3327.0017147045696
# Iteration 5, inertia 3324.090218365378
# Iteration 6, inertia 3322.6703133589513
# Iteration 7, inertia 3321.723089098795
# Iteration 8, inertia 3320.992658522703
# Iteration 9, inertia 3320.069219503316
# Iteration 10, inertia 3318.8869766911303
# Iteration 11, inertia 3317.682786372529
# Iteration 12, inertia 3316.9403446858964
# Iteration 13, inertia 3316.5283479314326
# Iteration 14, inertia 3316.32586112357
# Iteration 15, inertia 3316.192142007274
# Iteration 16, inertia 3316.1166584249904
# Iteration 17, inertia 3316.098751300144
# Iteration 18, inertia 3316.09663496918
# Converged at iteration 18: strict convergence.
# Initialization complete
# Iteration 0, inertia 5981.359247287316
# Iteration 1, inertia 3392.1592600590016
# Iteration 2, inertia 3352.472622357687
# Iteration 3, inertia 3340.212566944122
# Iteration 4, inertia 3336.8769176409105
# Iteration 5, inertia 3334.3992213299794
# Iteration 6, inertia 3332.8796221869943
# Iteration 7, inertia 3331.78219325093
# Iteration 8, inertia 3330.984880924501
# Iteration 9, inertia 3330.450575800791
# Iteration 10, inertia 3330.0211882273734
# Iteration 11, inertia 3329.6222840970768
# Iteration 12, inertia 3329.3215949703954
# Iteration 13, inertia 3329.091165265973
# Iteration 14, inertia 3328.84795793073
# Iteration 15, inertia 3328.6627771901285
# Iteration 16, inertia 3328.515774811034
# Iteration 17, inertia 3328.384440454597
# Iteration 18, inertia 3328.3127290799334
# Iteration 19, inertia 3328.277896766299
# Iteration 20, inertia 3328.261980606384
# Iteration 21, inertia 3328.247979821123
# Iteration 22, inertia 3328.2439520813227
# Iteration 23, inertia 3328.2421455755252
# Converged at iteration 23: strict convergence.
# Initialization complete
# Iteration 0, inertia 6049.110407339191
# Iteration 1, inertia 3401.5646909086418
# Iteration 2, inertia 3355.96787826323
# Iteration 3, inertia 3343.513720455831
# Iteration 4, inertia 3337.3482938491215
# Iteration 5, inertia 3333.2332985991316
# Iteration 6, inertia 3330.448597957415
# Iteration 7, inertia 3328.68138548594
# Iteration 8, inertia 3327.403685239246
# Iteration 9, inertia 3326.325121472068
# Iteration 10, inertia 3324.7787347993635
# Iteration 11, inertia 3321.5231332479916
# Iteration 12, inertia 3320.269166027796
# Iteration 13, inertia 3319.6208738048263
# Iteration 14, inertia 3319.2496581224436
# Iteration 15, inertia 3319.0041281261715
# Iteration 16, inertia 3318.7471920607327
# Iteration 17, inertia 3318.5485698972716
# Iteration 18, inertia 3318.3923269159845
# Iteration 19, inertia 3318.2685360423466
# Iteration 20, inertia 3318.1537100319474
# Iteration 21, inertia 3318.065083090911
# Iteration 22, inertia 3317.9915742503517
# Iteration 23, inertia 3317.928157939599
# Iteration 24, inertia 3317.8752736602432
# Iteration 25, inertia 3317.837680415411
# Iteration 26, inertia 3317.8202789887937
# Iteration 27, inertia 3317.8102508396887
# Iteration 28, inertia 3317.801706771874
# Converged at iteration 28: strict convergence.
# Initialization complete
# Iteration 0, inertia 5958.427498675794
# Iteration 1, inertia 3398.240705875561
# Iteration 2, inertia 3352.102467455685
# Iteration 3, inertia 3337.8588623677483
# Iteration 4, inertia 3333.6749856458437
# Iteration 5, inertia 3332.1191790299335
# Iteration 6, inertia 3331.282516102917
# Iteration 7, inertia 3330.959477293959
# Iteration 8, inertia 3330.8001706602013
# Iteration 9, inertia 3330.6984160964143
# Iteration 10, inertia 3330.6160958258088
# Iteration 11, inertia 3330.5408137864883
# Iteration 12, inertia 3330.4736892676656
# Iteration 13, inertia 3330.4059497623302
# Iteration 14, inertia 3330.328497595873
# Iteration 15, inertia 3330.2486059829366
# Iteration 16, inertia 3330.1981876297077
# Iteration 17, inertia 3330.1501149450296
# Iteration 18, inertia 3330.1063685960066
# Iteration 19, inertia 3330.0574780236525
# Iteration 20, inertia 3330.0191520378016
# Iteration 21, inertia 3329.9922336377986
# Iteration 22, inertia 3329.973884065809
# Iteration 23, inertia 3329.9656378229415
# Iteration 24, inertia 3329.9520381873763
# Iteration 25, inertia 3329.944537975374
# Iteration 26, inertia 3329.9360902847175
# Iteration 27, inertia 3329.916476922698
# Iteration 28, inertia 3329.9054664231467
# Converged at iteration 28: strict convergence.

# %% [markdown]
# Labels for the training set:

# %%
y_train = y_pred

# %% [markdown]
# Labels for the test set:

# %%
y_test = kmeans.predict(X_test)

# %% [markdown]
# Now that we have the labels, let's plot the t-SNE. scatterplot again and see if we have any obvious clusters:

# %%
# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", len(set(y_pred)))

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, legend='full', palette=palette)
plt.title("t-SNE Covid-19 Articles - Clustered")
# plt.savefig("plots/t-sne_covid19_label.png")
plt.show()
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# That looks pretty promising. It can be seen that articles from the same cluster are near each other, forming groups. There are still overlaps. So we will have to see if we can improve this by changing the cluster size, using another clustering algorithm, or different feature size. We can also consider not using 2-grams, or HashVectorizer. We can try 3-grams, 4-grams, or plain text as our instances and vectorize them using either HashVectorizer, Tf-idfVectorizer, or Burrows Wheeler Transform Distance. <br>
#
# Before we try another method for clustering, we want to see how well it will classify using the labels we just created using K-Means.

# %% [markdown]
# # Classify

# %% [markdown]
# ### Helper Function:

# %%
# function to print out classification model report
def classification_report(model_name, test, pred):
    from sklearn.metrics import precision_score, recall_score
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    
    print(model_name, ":\n")
    print("Accuracy Score: ", '{:,.3f}'.format(float(accuracy_score(test, pred)) * 100), "%")
    print("     Precision: ", '{:,.3f}'.format(float(precision_score(test, pred, average='micro')) * 100), "%")
    print("        Recall: ", '{:,.3f}'.format(float(recall_score(test, pred, average='micro')) * 100), "%")
    print("      F1 score: ", '{:,.3f}'.format(float(f1_score(test, pred, average='micro')) * 100), "%")

# %% [markdown]
# ### Random Forest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# random forest classifier instance
forest_clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# cross validation on the training set 
forest_scores = cross_val_score(forest_clf, X_train, y_train, cv=3, n_jobs=-1)

# print out the mean of the cross validation scores
print("Accuracy: ", '{:,.3f}'.format(float(forest_scores.mean()) * 100), "%")
# Out:
# Accuracy:  69.307 %

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_score, recall_score

# cross validate predict on the training set
forest_train_pred = cross_val_predict(forest_clf, X_train, y_train, cv=3, n_jobs=-1)

# print precision and recall scores
print("Precision: ", '{:,.3f}'.format(float(precision_score(y_train, forest_train_pred, average='macro')) * 100), "%")
print("   Recall: ", '{:,.3f}'.format(float(recall_score(y_train, forest_train_pred, average='macro')) * 100), "%")
# Out:
# Precision:  79.628 %
#    Recall:  63.055 %

# %%
# first train the model
forest_clf.fit(X_train, y_train)

# make predictions on the test set
forest_pred = forest_clf.predict(X_test)

# %%
# print out the classification report
classification_report("Random Forest Classifier Report (Test Set)", y_test, forest_pred)
# Out:
# Random Forest Classifier Report (Test Set) :
#
# Accuracy Score:  70.950 %
#      Precision:  70.950 %
#         Recall:  70.950 %
#       F1 score:  70.950 %

# %% [markdown]
# It looks like it doesn't overfit, which is good news. But results can be better than ~70-80%.

# %% [markdown]
# # Vectorize Using Tf-idf with Plain Text
# Let's see if we will be able to get better clusters using plain text as instances rather than 2-grams and vectorize it using Tf-idf. Last time we separated the dataset into test and training sets because we wanted to do classification with the labels we got through clustering. This time we will just use the all dataset because the goal is to cluster all literature.

# %% [markdown]
# ### Vectorize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=2**10)
X = vectorizer.fit_transform(df_covid['body_text'].values)

# %%
X.shape
# Out:
# (5523, 1024)

# %% [markdown]
# # MiniBatchKMeans with Plain text and Tf-idf

# %% [markdown]
# Again, let's try to get our labels. We will choose 10 clusters again. This time, we will use MiniBatchKMeans as it is faster with more data:

# %%
from sklearn.cluster import MiniBatchKMeans

k = 15
kmeans = MiniBatchKMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)

# %% [markdown]
# Get the labels:

# %%
y = y_pred

# %% [markdown]
# # Dimensionality Reduction with t-SNE (Plain text and Tf-idf)

# %% [markdown]
# Let's reduce the dimensionality using t-SNE again:

# %%
from sklearn.manifold import TSNE

tsne = TSNE(verbose=1)
X_embedded = tsne.fit_transform(X.toarray())
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\sched\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5523 samples in 0.021s...
# [t-SNE] Computed neighbors for 5523 samples in 2.479s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5523
# [t-SNE] Computed conditional probabilities for sample 2000 / 5523
# [t-SNE] Computed conditional probabilities for sample 3000 / 5523
# [t-SNE] Computed conditional probabilities for sample 4000 / 5523
# [t-SNE] Computed conditional probabilities for sample 5000 / 5523
# [t-SNE] Computed conditional probabilities for sample 5523 / 5523
# [t-SNE] Mean sigma: 0.165395
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.449860
# [t-SNE] KL divergence after 1000 iterations: 2.015492

# %% [markdown]
# ### Plot t-SNE

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", len(set(y)))

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
plt.title("t-SNE Covid-19 Articles - Clustered(K-Means) - Tf-idf with Plain Text")
# plt.savefig("plots/t-sne_covid19_label_TFID.png")
plt.show()
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This time we are able to see the clusters more clearly. There are clusters that further apart from each other. I can also start to see that there is possibly more than 10 clusters we need to identify using k-means.

# %% [markdown]
# # Dimensionality Reduction with PCA (Plain text and Tf-idf)

# %% [markdown]
# t-SNE doesn't scale well. This is why run-time of this Notebook is about 40 minutes to 1 hour with an average computer. Let's try to see if we dan achive good results with PCA as it scales very well with larger datasets and dimensions:

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca_result = pca.fit_transform(X.toarray())

# %% [markdown]
# ### Plot PCA

# %%
# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", len(set(y)))

# plot
sns.scatterplot(pca_result[:,0], pca_result[:,1], hue=y, legend='full', palette=palette)
plt.title("PCA Covid-19 Articles - Clustered (K-Means) - Tf-idf with Plain Text")
# plt.savefig("plots/pca_covid19_label_TFID.png")
plt.show()
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Sometimes it may be easier to see the results in a 3 dimensional plot. So let's try to do that:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=pca_result[:,0], 
    ys=pca_result[:,1], 
    zs=pca_result[:,2], 
    c=y, 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.title("PCA Covid-19 Articles (3D) - Clustered (K-Means) - Tf-idf with Plain Text")
# plt.savefig("plots/pca_covid19_label_TFID_3d.png")
plt.show()
# Out:
# C:\Users\sched\AppData\Local\Temp/ipykernel_9480/3963984120.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.figure(figsize=(16,10)).gca(projection='3d')

# %% [markdown]
# # More Clusters?
# On our previous plot we could see that there is more clusters than only 10. Let's try to label them:

# %%
from sklearn.cluster import MiniBatchKMeans

k = 20
kmeans = MiniBatchKMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)
y = y_pred

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import random 

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# let's shuffle the list so distinct colors stay next to each other
palette = sns.hls_palette(20, l=.4, s=.9)
random.shuffle(palette)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
plt.title("t-SNE Covid-19 Articles - Clustered(K-Means) - Tf-idf with Plain Text")
# plt.savefig("plots/t-sne_covid19_20label_TFID.png")
plt.show()
# Out:
# C:\Users\sched\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It would be helpful if we have a demo tool that can be used to see what articles are identified as similar using our Clustering and Dimensionality Reduction, right? Let's put together a interactive scatter plot of t-SNE to do that.

# %% [markdown]
# # Interactive t-SNE

# %%
from bokeh.models import ColumnDataSource, HoverTool, LinearColorMapper, CustomJS
from bokeh.palettes import Category20
from bokeh.transform import linear_cmap
from bokeh.io import output_file, show
from bokeh.transform import transform
from bokeh.io import output_notebook
from bokeh.plotting import figure
from bokeh.layouts import column
from bokeh.models import RadioButtonGroup
from bokeh.models import TextInput
from bokeh.layouts import gridplot
from bokeh.models import Div
from bokeh.models import Paragraph
from bokeh.layouts import column, widgetbox

output_notebook()
y_labels = y_pred

# data sources
source = ColumnDataSource(data=dict(
    x= X_embedded[:,0], 
    y= X_embedded[:,1],
    x_backup = X_embedded[:,0],
    y_backup = X_embedded[:,1],
    desc= y_labels, 
    titles= df_covid['title'],
    authors = df_covid['authors'],
    journal = df_covid['journal'],
    abstract = df_covid['abstract_summary'],
    labels = ["C-" + str(x) for x in y_labels]
    ))

# hover over information
hover = HoverTool(tooltips=[
    ("Title", "@titles{safe}"),
    ("Author(s)", "@authors"),
    ("Journal", "@journal"),
    ("Abstract", "@abstract{safe}"),
],
                 point_policy="follow_mouse")

# map colors
mapper = linear_cmap(field_name='desc', 
                     palette=Category20[20],
                     low=min(y_labels) ,high=max(y_labels))

# prepare the figure
p = figure(plot_width=800, plot_height=800, 
           tools=[hover, 'pan', 'wheel_zoom', 'box_zoom', 'reset'], 
           title="t-SNE Covid-19 Articles, Clustered(K-Means), Tf-idf with Plain Text", 
           toolbar_location="right")

# plot
p.scatter('x', 'y', size=5, 
          source=source,
          fill_color=mapper,
          line_alpha=0.3,
          line_color="black",
          legend_label = 'labels')

# add callback to control 
callback = CustomJS(args=dict(p=p, source=source), code="""
            
            var radio_value = cb_obj.active;
            var data = source.data; 
            
            x = data['x'];
            y = data['y'];
            
            x_backup = data['x_backup'];
            y_backup = data['y_backup'];
            
            labels = data['desc'];
            
            if (radio_value == '20') {
                for (i = 0; i < x.length; i++) {
                    x[i] = x_backup[i];
                    y[i] = y_backup[i];
                }
            }
            else {
                for (i = 0; i < x.length; i++) {
                    if(labels[i] == radio_value) {
                        x[i] = x_backup[i];
                        y[i] = y_backup[i];
                    } else {
                        x[i] = undefined;
                        y[i] = undefined;
                    }
                }
            }


        source.change.emit();
        """)

# callback for searchbar
keyword_callback = CustomJS(args=dict(p=p, source=source), code="""
            
            var text_value = cb_obj.value;
            var data = source.data; 
            
            x = data['x'];
            y = data['y'];
            
            x_backup = data['x_backup'];
            y_backup = data['y_backup'];
            
            abstract = data['abstract'];
            titles = data['titles'];
            authors = data['authors'];
            journal = data['journal'];

            for (i = 0; i < x.length; i++) {
                if(abstract[i].includes(text_value) || 
                   titles[i].includes(text_value) || 
                   authors[i].includes(text_value) || 
                   journal[i].includes(text_value)) {
                    x[i] = x_backup[i];
                    y[i] = y_backup[i];
                } else {
                    x[i] = undefined;
                    y[i] = undefined;
                }
            }
            


        source.change.emit();
        """)

# option
option = RadioButtonGroup(labels=["C-0", "C-1", "C-2",
                                  "C-3", "C-4", "C-5",
                                  "C-6", "C-7", "C-8",
                                  "C-9", "C-10", "C-11",
                                  "C-12", "C-13", "C-14",
                                  "C-15", "C-16", "C-17",
                                  "C-18", "C-19", "All"], 
                          active=20,callback=callback)

# search box
keyword = TextInput(title="Search:", callback=keyword_callback)

#header
header = Div(text="""<h1>COVID-19 Literature Cluster</h1>""")

# show
show(column(header, widgetbox(option, keyword),p))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1500">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9480/336346480.py in <module>
#     131
#     132 # option
# --> 133 option = RadioButtonGroup(labels=["C-0", "C-1", "C-2",
#     134                                   "C-3", "C-4", "C-5",
#     135                                   "C-6", "C-7", "C-8",
#
# ~\anaconda3\lib\site-packages\bokeh\model\model.py in __init__(self, **kwargs)
#     126         kwargs.pop("id", None)
#     127
# --> 128         super().__init__(**kwargs)
#     129         default_theme.apply_to_model(self)
#     130
#
# ~\anaconda3\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     204
#     205         for name, value in properties.items():
# --> 206             setattr(self, name, value)
#     207
#     208         self._initialized = True
#
# ~\anaconda3\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     234             return super().__setattr__(name, value)
#     235
# --> 236         self._raise_attribute_error_with_matches(name, properties)
#     237
#     238     def __getattr__(self, name: str) -> Unknown:
#
# ~\anaconda3\lib\site-packages\bokeh\core\has_props.py in _raise_attribute_error_with_matches(self, name, properties)
#     270             matches, text = sorted(properties), "possible"
#     271
# --> 272         raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#     273
#     274     def __str__(self) -> str:
#
# AttributeError: unexpected attribute 'callback' to RadioButtonGroup, similar attributes are js_event_callbacks

# %% [markdown]
# #### Please see the tools on right top.
# #### If the text doesn't fit in the screen on the above plot when hover, please try the 'Box Zoom' tool to zoom to the area where the target plot is. This will help the hover message to fit the screen.
# #### Use the 'Reset' button to revert the zoom.

# %% [markdown]
# This notebook is adaption from the following kaggle notebook https://www.kaggle.com/maksimeren/covid-19-literature-clustering
# ### You can find the full version of the interactive plot here on GitHub:
# #### https://maksimekin.github.io/COVID19-Literature-Clustering/plots/t-sne_covid-19_interactive.html
